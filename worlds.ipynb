# %%
import pandas as pd
import seaborn as sns
import re

# %% [markdown]
# Matty

# %%
#matty
df1 = pd.read_csv('matty.csv')

# %%
df1.head()
# Out:
#         id  pos  round_id  best  average                name country_iso2  \
# 0  5632136    1    819537   435      533  Matty Hiroto Inaba           US
# 1  5632265    1    819538   434      560  Matty Hiroto Inaba           US
# 2  5632352    1    819539   460      541  Matty Hiroto Inaba           US
# 3  5632376    9    819540   250      315  Matty Hiroto Inaba           US
# 4  5632463    4    819541   176      256  Matty Hiroto Inaba           US
#
#                     competition_id event_id round_type_id  ...      wca_id  \
# 0  BayAreaSpeedcubin55SanRamon2024      333             1  ...  2016INAB01
# 1  BayAreaSpeedcubin55SanRamon2024      333             2  ...  2016INAB01
# 2  BayAreaSpeedcubin55SanRamon2024      333             f  ...  2016INAB01
# 3  BayAreaSpeedcubin55SanRamon2024      222             1  ...  2016INAB01
# 4  BayAreaSpeedcubin55SanRamon2024      222             f  ...  2016INAB01
#
# ...

# %%
df_matty = df1.drop(columns=["single_seconds","competition_name","attempts","start_date","round_type_id","round_id", "regional_single_record", "regional_average_record", "best", "average", "country_iso2", "format_id", "id", "competition_id", "best_index", "worst_index"])
df_matty = df_matty[df_matty['event_id']=='333']

# %%
df_matty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 0 to 169
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pos               51 non-null     int64
#  1   name              51 non-null     object
#  2   event_id          51 non-null     object
#  3   wca_id            51 non-null     object
#  4   attempts          51 non-null     object
#  5   competition_name  51 non-null     object
#  6   start_date        51 non-null     object
#  7   single_seconds    51 non-null     float64
#  8   average_seconds   51 non-null     float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 4.0+ KB

# %%
df_matty.head()
# Out:
#     pos                name event_id      wca_id  average_seconds
# 0     1  Matty Hiroto Inaba      333  2016INAB01             5.33
# 1     1  Matty Hiroto Inaba      333  2016INAB01             5.60
# 2     1  Matty Hiroto Inaba      333  2016INAB01             5.41
# 9     2  Matty Hiroto Inaba      333  2016INAB01             6.08
# 10    1  Matty Hiroto Inaba      333  2016INAB01             5.89

# %%
pd.to_datetime(df_matty["start_date"])
#df_predic[df_predic["start_date"].dt.year == 2025].info()
# Out:
# 0     2024-01-14
# 1     2024-01-14
# 2     2024-01-14
# 3     2024-01-14
# 4     2024-01-14
#          ...
# 224   2025-06-13
# 225   2025-06-13
# 226   2025-06-13
# 227   2025-06-13
# 228   2025-06-13
# Name: start_date, Length: 229, dtype: datetime64[ns]

# %% [markdown]
# Bofan

# %%
df = pd.read_csv('bofan.csv')

# %%
df.head()
# Out:
#         id  pos  round_id  best  average               name country_iso2  \
# 0  5768269    2    838487   527      562  Bofan Zhang (张博藩)           CN
# 1  5768420    4    838488   503      578  Bofan Zhang (张博藩)           CN
# 2  5768499    3    838489   518      556  Bofan Zhang (张博藩)           CN
# 3  5768509    3    838490   139      148  Bofan Zhang (张博藩)           CN
# 4  5768601    3    838491   138      185  Bofan Zhang (张博藩)           CN
#
#        competition_id event_id round_type_id  ...      wca_id  \
# 0  HangzhouSpring2024      333             1  ...  2021ZHAN01
# 1  HangzhouSpring2024      333             2  ...  2021ZHAN01
# 2  HangzhouSpring2024      333             f  ...  2021ZHAN01
# 3  HangzhouSpring2024      222             d  ...  2021ZHAN01
# 4  HangzhouSpring2024      222             f  ...  2021ZHAN01
#
#                     attempts best_index  worst_index  regional_single_record  \
# ...

# %%
df_bofan = df.drop(columns=["single_seconds","competition_name","attempts","start_date","round_type_id","round_id", "regional_single_record", "regional_average_record", "best", "average", "country_iso2", "format_id", "id", "competition_id", "best_index", "worst_index"])
df_bofan = df_bofan[df_bofan['event_id']=='333']

# %%
df_bofan.info()
pd.to_datetime(df_bofan["start_date"])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, 0 to 139
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pos               52 non-null     int64
#  1   name              52 non-null     object
#  2   event_id          52 non-null     object
#  3   wca_id            52 non-null     object
#  4   attempts          52 non-null     object
#  5   competition_name  52 non-null     object
#  6   start_date        52 non-null     object
#  7   single_seconds    52 non-null     float64
#  8   average_seconds   52 non-null     float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 4.1+ KB
# 0     2024-03-02
# 1     2024-03-02
# 2     2024-03-02
# 9     2024-04-05
# 10    2024-04-05
# 11    2024-04-05
# 19    2024-04-21
# 20    2024-04-21
# 21    2024-04-21
# 30    2024-06-01
# 31    2024-06-01
# 32    2024-06-01
# 41    2024-07-28
# 42    2024-07-28
# 43    2024-07-28
# ...

# %%
df_bofan.head()
# Out:
#     pos               name event_id      wca_id  average_seconds
# 0     2  Bofan Zhang (张博藩)      333  2021ZHAN01             5.62
# 1     4  Bofan Zhang (张博藩)      333  2021ZHAN01             5.78
# 2     3  Bofan Zhang (张博藩)      333  2021ZHAN01             5.56
# 9     2  Bofan Zhang (张博藩)      333  2021ZHAN01             5.72
# 10    2  Bofan Zhang (张博藩)      333  2021ZHAN01             6.06

# %% [markdown]
# Luke

# %%
df2 = pd.read_csv('luke.csv')
df2.head()
# Out:
#         id  pos  round_id  best  average          name country_iso2  \
# 0  5614352    2    816220   538      659  Luke Garrett           US
# 1  5614459    1    816221   549      608  Luke Garrett           US
# 2  5614512    1    816222   471      534  Luke Garrett           US
# 3  5614532    6    816223   110      241  Luke Garrett           US
# 4  5614627    1    816224    93      126  Luke Garrett           US
#
#              competition_id event_id round_type_id  ...      wca_id  \
# 0  MilwaukeeCubingMania2024      333             1  ...  2017GARR05
# 1  MilwaukeeCubingMania2024      333             2  ...  2017GARR05
# 2  MilwaukeeCubingMania2024      333             f  ...  2017GARR05
# 3  MilwaukeeCubingMania2024      222             1  ...  2017GARR05
# 4  MilwaukeeCubingMania2024      222             f  ...  2017GARR05
#
#                     attempts best_index  worst_index  regional_single_record  \
# ...

# %%
df_luke = df2.drop(columns=["single_seconds","competition_name","attempts","start_date","round_type_id","round_id", "regional_single_record", "regional_average_record", "best", "average", "country_iso2", "format_id", "id", "competition_id", "best_index", "worst_index"])
df_luke = df_luke[df_luke['event_id']=='333']
df_luke.head()
# Out:
#     pos          name event_id      wca_id  average_seconds
# 0     2  Luke Garrett      333  2017GARR05             6.59
# 1     1  Luke Garrett      333  2017GARR05             6.08
# 2     1  Luke Garrett      333  2017GARR05             5.34
# 24    1  Luke Garrett      333  2017GARR05             5.93
# 25    1  Luke Garrett      333  2017GARR05             6.07

# %% [markdown]
# Teodor

# %%
df3 = pd.read_csv('teodor.csv')
df3.head()
# Out:
#         id  pos  round_id  best  average           name country_iso2  \
# 0  5643214    3    833282   537      792  Teodor Zajder           PL
# 1  5643339    3    833283   639      825  Teodor Zajder           PL
# 2  5643432    3    833284   680      779  Teodor Zajder           PL
# 3  5643440    1    833285   125      144  Teodor Zajder           PL
# 4  5643540    3    833286   100      158  Teodor Zajder           PL
#
#   competition_id event_id round_type_id  ...      wca_id  \
# 0       GLSI2024      333             1  ...  2021ZAJD03
# 1       GLSI2024      333             2  ...  2021ZAJD03
# 2       GLSI2024      333             f  ...  2021ZAJD03
# 3       GLSI2024      222             1  ...  2021ZAJD03
# 4       GLSI2024      222             f  ...  2021ZAJD03
#
#                      attempts best_index  worst_index  regional_single_record  \
# 0   [925, 684, 537, 863, 830]          2            0                     NaN
# ...

# %%
df_teodor = df3.drop(columns=["single_seconds","competition_name","attempts","start_date","round_type_id","round_id", "regional_single_record", "regional_average_record", "best", "average", "country_iso2", "format_id", "id", "competition_id", "best_index", "worst_index"])
df_teodor = df_teodor[df_teodor['event_id']=='333']
df_teodor.head()
# Out:
#     pos           name event_id      wca_id  average_seconds
# 0     3  Teodor Zajder      333  2021ZAJD03             7.92
# 1     3  Teodor Zajder      333  2021ZAJD03             8.25
# 2     3  Teodor Zajder      333  2021ZAJD03             7.79
# 12    2  Teodor Zajder      333  2021ZAJD03             7.50
# 13    2  Teodor Zajder      333  2021ZAJD03             7.35

# %% [markdown]
# **Max**

# %%
df4 = pd.read_csv('max.csv')
df4.head()
# Out:
#         id  pos  round_id  best  average      name country_iso2  \
# 0  5620113    1    823348   489      592  Max Park           US
# 1  5620280    1    823349   517      551  Max Park           US
# 2  5620397    1    823350   481      528  Max Park           US
# 3  5620559    1    828741  1951     2072  Max Park           US
# 4  5620658    1    828742  1970     2226  Max Park           US
#
#    competition_id event_id round_type_id  ...      wca_id  \
# 0  UCSDWinter2024      333             1  ...  2012PARK03
# 1  UCSDWinter2024      333             2  ...  2012PARK03
# 2  UCSDWinter2024      333             f  ...  2012PARK03
# 3  UCSDWinter2024      444             d  ...  2012PARK03
# 4  UCSDWinter2024      444             f  ...  2012PARK03
#
#                          attempts best_index  worst_index  \
# 0       [612, 489, 550, 614, 714]          1            4
# 1       [545, 579, 517, 535, 574]          2            1
# ...

# %%
df_max = df4.drop(columns=["single_seconds","competition_name","attempts","start_date","round_type_id","round_id", "regional_single_record", "regional_average_record", "best", "average", "country_iso2", "format_id", "id", "competition_id", "best_index", "worst_index"])
df_max = df_max[df_max['event_id']=='333']
df_max.head()
# Out:
#    pos      name event_id      wca_id  average_seconds
# 0    1  Max Park      333  2012PARK03             5.92
# 1    1  Max Park      333  2012PARK03             5.51
# 2    1  Max Park      333  2012PARK03             5.28
# 8    1  Max Park      333  2012PARK03             5.68
# 9    1  Max Park      333  2012PARK03             5.68

# %% [markdown]
# Ruihang

# %%
df5 = pd.read_csv('ruihang.csv')
df5.head()
# Out:
#         id  pos  round_id  best  average              name country_iso2  \
# 0  5859149    6    838516   509      739  Ruihang Xu (许瑞航)           CN
# 1  5859323    1    838517   452      484  Ruihang Xu (许瑞航)           CN
# 2  5859413    1    838518   409      574  Ruihang Xu (许瑞航)           CN
# 3  5859431    1    838519  2177     2359  Ruihang Xu (许瑞航)           CN
# 4  5859559    1    838520  1990     2282  Ruihang Xu (许瑞航)           CN
#
#    competition_id event_id round_type_id  ...      wca_id  \
# 0  HuzhouOpen2024      333             1  ...  2017XURU04
# 1  HuzhouOpen2024      333             2  ...  2017XURU04
# 2  HuzhouOpen2024      333             f  ...  2017XURU04
# 3  HuzhouOpen2024      444             d  ...  2017XURU04
# 4  HuzhouOpen2024      444             f  ...  2017XURU04
#
#                          attempts best_index  worst_index  \
# 0       [604, 1077, -1, 509, 535]          3            2
# 1       [465, 520, 593, 452, 467]          3            2
# ...

# %%
df_ruihang = df5.drop(columns=["single_seconds","competition_name","attempts","start_date","round_type_id","round_id", "regional_single_record", "regional_average_record", "best", "average", "country_iso2", "format_id", "id", "competition_id", "best_index", "worst_index"])
df_ruihang = df_ruihang[df_ruihang['event_id']=='333']
df_ruihang.head()
# Out:
#    pos              name event_id      wca_id  average_seconds
# 0    6  Ruihang Xu (许瑞航)      333  2017XURU04             7.39
# 1    1  Ruihang Xu (许瑞航)      333  2017XURU04             4.84
# 2    1  Ruihang Xu (许瑞航)      333  2017XURU04             5.74
# 6    3  Ruihang Xu (许瑞航)      333  2017XURU04             5.85
# 7    2  Ruihang Xu (许瑞航)      333  2017XURU04             5.41

# %% [markdown]
# Tymon

# %%
df6 = pd.read_csv("tymon.csv")
df6.head()
# Out:
#         id  pos  round_id  best  average              name country_iso2  \
# 0  5610306    1    822436   504      577  Tymon Kolasiński           PL
# 1  5610486    1    822437   392      510  Tymon Kolasiński           PL
# 2  5610614    1    822438   472      510  Tymon Kolasiński           PL
# 3  5610675    1    822452   526      580  Tymon Kolasiński           PL
# 4  5610691    1    822439  1943     2331  Tymon Kolasiński           PL
#
#         competition_id  event_id round_type_id  ...      wca_id  \
# 0  CubingatTheCube2024       333             1  ...  2016KOLA02
# 1  CubingatTheCube2024       333             2  ...  2016KOLA02
# 2  CubingatTheCube2024       333             3  ...  2016KOLA02
# 3  CubingatTheCube2024       333             f  ...  2016KOLA02
# 4  CubingatTheCube2024       444             d  ...  2016KOLA02
#
#                          attempts best_index  worst_index  \
# 0       [730, 599, 620, 511, 504]          4            0
# ...

# %%
df_tymon = df6.drop(columns=["single_seconds","competition_name","attempts","start_date","round_type_id","round_id", "regional_single_record", "regional_average_record", "best", "average", "country_iso2", "format_id", "id", "competition_id", "best_index", "worst_index"])
df_tymon = df_tymon[df_tymon['event_id']==333]
df_tymon.tail()
# Out:
#     pos              name  event_id      wca_id  average_seconds
# 49    1  Tymon Kolasiński       333  2016KOLA02             5.15
# 52    1  Tymon Kolasiński       333  2016KOLA02             5.03
# 53    1  Tymon Kolasiński       333  2016KOLA02             4.97
# 54    1  Tymon Kolasiński       333  2016KOLA02             5.54
# 55    1  Tymon Kolasiński       333  2016KOLA02             5.34

# %% [markdown]
# xuanyi

# %%
df7 = pd.read_csv('xuanyi.csv')
df7.head()
# Out:
#         id  pos  round_id  best  average               name country_iso2  \
# 0  5768270    3    838487   521      563  Xuanyi Geng (耿暄一)           CN
# 1  5768418    2    838488   532      552  Xuanyi Geng (耿暄一)           CN
# 2  5768500    4    838489   464      563  Xuanyi Geng (耿暄一)           CN
# 3  5796596    2    839200   493      554  Xuanyi Geng (耿暄一)           CN
# 4  5796785    3    839201   514      593  Xuanyi Geng (耿暄一)           CN
#
#        competition_id event_id round_type_id  ...      wca_id  \
# 0  HangzhouSpring2024      333             1  ...  2023GENG02
# 1  HangzhouSpring2024      333             2  ...  2023GENG02
# 2  HangzhouSpring2024      333             f  ...  2023GENG02
# 3   LuoyangSpring2024      333             1  ...  2023GENG02
# 4   LuoyangSpring2024      333             2  ...  2023GENG02
#
#                     attempts best_index  worst_index  regional_single_record  \
# ...

# %%
df_xuanyi = df7.drop(columns=["single_seconds","competition_name","attempts","start_date","round_type_id","round_id", "regional_single_record", "regional_average_record", "best", "average", "country_iso2", "format_id", "id", "competition_id", "best_index", "worst_index"])
df_xuanyi = df_xuanyi[df_xuanyi['event_id']=="333"]
df_xuanyi.tail()
# Out:
#      pos               name event_id      wca_id  average_seconds
# 114    2  Xuanyi Geng (耿暄一)      333  2023GENG02             4.64
# 115    1  Xuanyi Geng (耿暄一)      333  2023GENG02             4.59
# 116    2  Xuanyi Geng (耿暄一)      333  2023GENG02             4.84
# 117    2  Xuanyi Geng (耿暄一)      333  2023GENG02             5.24
# 118    1  Xuanyi Geng (耿暄一)      333  2023GENG02             4.95

# %% [markdown]
# Yiheng

# %%
df8 = pd.read_csv('yiheng.csv')
df8.head()
# Out:
#         id  pos  round_id  best  average               name country_iso2  \
# 0  5680001    1    833508   467      528  Yiheng Wang (王艺衡)           CN
# 1  5680144    1    833509   442      487  Yiheng Wang (王艺衡)           CN
# 2  5680204    1    833510   407      506  Yiheng Wang (王艺衡)           CN
# 3  5680224    1    833511   113      139  Yiheng Wang (王艺衡)           CN
# 4  5680335    1    833512    76      110  Yiheng Wang (王艺衡)           CN
#
#    competition_id event_id round_type_id  ...      wca_id  \
# 0  FushunOpen2024      333             1  ...  2019WANY36
# 1  FushunOpen2024      333             2  ...  2019WANY36
# 2  FushunOpen2024      333             f  ...  2019WANY36
# 3  FushunOpen2024      222             d  ...  2019WANY36
# 4  FushunOpen2024      222             f  ...  2019WANY36
#
#                      attempts best_index  worst_index  regional_single_record  \
# 0  [493, 558, 1164, 467, 532]          3            2                     NaN
# ...

# %%
df_yiheng = df8.drop(columns=["single_seconds","competition_name","attempts","start_date","round_type_id","round_id", "regional_single_record", "regional_average_record", "best", "average", "country_iso2", "format_id", "id", "competition_id", "best_index", "worst_index"])
df_yiheng = df_yiheng[df_yiheng['event_id']=="333"]
df_yiheng.tail()
# Out:
#      pos               name event_id      wca_id  average_seconds
# 342    1  Yiheng Wang (王艺衡)      333  2019WANY36             4.44
# 343    2  Yiheng Wang (王艺衡)      333  2019WANY36             5.25
# 349    1  Yiheng Wang (王艺衡)      333  2019WANY36             3.98
# 350    1  Yiheng Wang (王艺衡)      333  2019WANY36             4.40
# 351    1  Yiheng Wang (王艺衡)      333  2019WANY36             4.09

# %%
df_predic = pd.concat([df_bofan, df_luke, df_matty, df_max, df_ruihang, df_teodor, df_tymon, df_xuanyi, df_yiheng], ignore_index=True)

# %%
df_predic.to_csv("df_worlds.csv", index=False)

# %%
df9 =pd.read_csv('df_worlds.csv')
df9.groupby('name').describe()
# Out:
#                       pos                                                 \
#                     count      mean       std  min   25%  50%  75%   max
# name
# Bofan Zhang (张博藩)    52.0  4.230769  4.114133  1.0  2.75  3.0  5.0  30.0
# Luke Garrett        164.0  1.810976  3.418768  1.0  1.00  1.0  2.0  41.0
# Matty Hiroto Inaba   51.0  1.647059  1.467290  1.0  1.00  1.0  1.0   7.0
# Max Park             73.0  1.082192  0.399772  1.0  1.00  1.0  1.0   4.0
# Ruihang Xu (许瑞航)     31.0  3.290323  2.208975  1.0  1.50  3.0  4.0   9.0
# Teodor Zajder       104.0  3.096154  4.716258  1.0  1.00  2.0  3.0  37.0
# Tymon Kolasiński     28.0  1.071429  0.262265  1.0  1.00  1.0  1.0   2.0
# Xuanyi Geng (耿暄一)   118.0  1.779661  0.763881  1.0  1.00  2.0  2.0   5.0
# Yiheng Wang (王艺衡)   131.0  1.236641  0.721452  1.0  1.00  1.0  1.0   7.0
#
#                    event_id         ...               average_seconds  \
#                       count   mean  ...    75%    max           count
# ...
